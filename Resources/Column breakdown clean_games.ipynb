# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from pathlib import Path

# %%
# csv to df for metacritic games master
file_path = Path("Cleaned df/clean_games.csv")
games_master_df = pd.read_csv(file_path)
games_master_df
# Out:
#        Unnamed: 0                                         Title  Release Date  \
# 0               0                           Burnout 3: Takedown  Sep  7, 2004
# 1               1                               Jet Grind Radio  Oct 30, 2000
# 2               2      Metal Gear Solid 4: Guns of the Patriots  Jun 12, 2008
# 3               3       Tom Clancy's Splinter Cell Chaos Theory  Mar 28, 2005
# 4               4                Call of Duty: Modern Warfare 2  Nov 10, 2009
# ...           ...                                           ...           ...
# 19312       19312  Family Party: 30 Great Games Obstacle Arcade  Dec  4, 2012
# 19313       19313                     Ride to Hell: Retribution  Jun 24, 2013
# 19314       19314                       Far Cry 5: Lost on Mars  Jul 17, 2018
# 19315       19315                                    Smash T.V.  Nov 24, 2005
# 19316       19316      JoJo's Bizarre Adventure: Eyes of Heaven  Jun 28, 2016
#
# ...

# %%
unique_column_values = games_master_df.nunique(axis=0)
unique_column_values
# Out:
# Unnamed: 0             19317
# Title                  12545
# Release Date            4657
# Genre                   2226
# Platforms                 22
# Developer               4706
# ESRB Rating                7
# ESRBs                   1331
# Meta Crtic score          85
# User Score                95
# Meta Critic Reviews      117
# user_reviews            1458
# Number of Players        397
# Game Summary           15203
# dtype: int64

# %%
Genres = games_master_df['Genre'].value_counts()
Genres
# Out:
# Action, Platformer, 2D                                                               548
# Role-Playing, Action RPG                                                             474
# Action Adventure, General                                                            419
# Action, Platformer, 3D                                                               308
# Adventure, General                                                                   300
#                                                                                     ...
# Action, Platformer, 3D, Action Adventure, Fantasy, General, Fantasy                    1
# Action Adventure, Adventure, General, 3D, Survival, First-Person                       1
# Simulation, Adventure, Third-Person, Virtual, Sci-Fi, Sci-Fi, Career                   1
# Action, General, Platformer, Shooter, 2D, Shoot-'Em-Up, Horizontal                     1
# Driving, Modern, Racing, Motorcycle, Motocross, Modern, Action Adventure, General      1
# ...

# %%
Platforms = games_master_df["Platforms"].value_counts()
Platforms
# Out:
# PC                  5030
# PlayStation 4       2088
# Xbox 360            1665
# Switch              1515
# PlayStation 2       1420
# PlayStation 3       1265
# Xbox One            1188
# Xbox                 794
# DS                   727
# Wii                  663
# PSP                  514
# GameCube             452
# Game Boy Advance     442
# 3DS                  397
# PlayStation Vita     258
# PlayStation 5        196
# PlayStation          189
# Wii U                186
# Xbox Series X        126
# Dreamcast            126
# Nintendo 64           71
# Stadia                 5
# Name: Platforms, dtype: int64

# %%
Player_count = games_master_df["Number of Players"].value_counts()
Player_count
# Out:
# 1 Player                                                              11643
# 1-2 Players                                                            1307
# 1-4 Players                                                            1032
# Up to 4 Players                                                         524
# 2 Players                                                               406
#                                                                       ...
# 1-2 Players, 2 Players 8 Players Online                                   1
# 1 Player, 32 Players Online Up to 64 Players                              1
# 32 Players Online Online Multiplayer                                      1
# 1-4 Players, Up to 10 Players                                             1
# Massively Multiplayer, Massively Multiplayer No Online Multiplayer        1
# Name: Number of Players, Length: 397, dtype: int64
